# %%
import pandas as pd
df=pd.read_csv("/content/job_dataset.csv")
df
# Out:
#                                               job_title  \
# 0     Technology Lead : Data Science I Machine Learning
# 1                   Software Engineer, Machine Learning
# 2           Experienced Over The Shoulder Mechanic- C17
# 3                                        Data Scientist
# 4                                      Python Developer
# ...                                                 ...
# 1578        Learning Integration-Analyst/Senior Analyst
# 1579                                   Business Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# 1581  Program Research Analyst – Sustainable Cities ...
# 1582                                       Data Analyst
#
#                                              company  \
# 0                                    Infosys Limited
# 1                                             Google
# 2                                             BOEING
# 3                                    Infosys Limited
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1583 entries, 0 to 1582
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     1583 non-null   object
#  1   company       1583 non-null   object
#  2   job_location  1583 non-null   object
#  3   job_summary   1583 non-null   object
#  4   post_date     1583 non-null   object
#  5   today         1583 non-null   object
#  6   job_salary    405 non-null    object
#  7   job_url       1583 non-null   object
# dtypes: object(8)
# memory usage: 99.1+ KB

# %%
df.size
# Out:
# 12664

# %%
df.shape
# Out:
# (1583, 8)

# %%
#1 Count the total number of null values present in every column.
df.isnull().sum()
# Out:
# job_title          0
# company            0
# job_location       0
# job_summary        0
# post_date          0
# today              0
# job_salary      1178
# job_url            0
# dtype: int64

# %%
#2. Count the total number of null values present in job_salary column.
df["job_salary"].isnull().sum()
# Out:
# 1178

# %%
#3. Count the total number of unique item or value present in a column
df.nunique()
# Out:
# job_title        965
# company          917
# job_location     169
# job_summary     1480
# post_date         80
# today              1
# job_salary       238
# job_url         1438
# dtype: int64

# %%
#4. Show the name of company's present in the dataset
df["company"].unique()
# Out:
# array(['Infosys Limited', 'Google', 'BOEING', 'AdTech Holding', 'Oracle',
#        'Atos', 'Infochola', 'BlueOptima', 'Impetus Technologies',
#        'Julia Computing', 'DTN', 'Infimetrics Info Solutions Pvt. Ltd.',
#        'UST Global', 'Tech Opportunity', 'Quantiphi', 'Mobotics',
#        'Maersk', 'Ideapoke', 'Honeywell', 'ServiceNow',
#        'Hacklab Solutions Private Limited', 'PeopleGrove', 'Lincode Labs',
#        'Sourcedesk Global',
#        'Mercedes-Benz Research and Development India...',
#        'Wadhwani Institute for Artificial Intelligence', 'MetaMap', 'EY',
#        'Alphanet Solution', 'Gex Search', 'Badatya Private Limited',
#        'Climate Connect', 'Financial Fabric', 'Recrosoft Technologies',
#        'Hitachi Vantara Corporation', 'Wipro Limited', '3loq',
#        'Brickendon Consulting', 'Intrics Solutions Pvt Ltd', 'PayPal',
#        "Angel's Virtual World", 'Hitachi', 'Excellence and Eminence LLP',
# ...

# %%
#5. Delete column post_date
df=df.drop(["post_date"],axis=1)
df
# Out:
#                                               job_title  \
# 0     Technology Lead : Data Science I Machine Learning
# 1                   Software Engineer, Machine Learning
# 2           Experienced Over The Shoulder Mechanic- C17
# 3                                        Data Scientist
# 4                                      Python Developer
# ...                                                 ...
# 1578        Learning Integration-Analyst/Senior Analyst
# 1579                                   Business Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# 1581  Program Research Analyst – Sustainable Cities ...
# 1582                                       Data Analyst
#
#                                              company  \
# 0                                    Infosys Limited
# 1                                             Google
# 2                                             BOEING
# 3                                    Infosys Limited
# ...

# %%
#6. Show the bar plot of job location, so that we can understand how many same job locations are there
import matplotlib.pyplot as plt
plt.figure(figsize=(150,20))
df["job_location"].value_counts().plot(kind="bar")

# %%
#7. show the company names from 10 to 20 rows
df.iloc[10:20,1].values
# Out:
# array(['Impetus Technologies', 'Google', 'Julia Computing', 'DTN',
#        'Infimetrics Info Solutions Pvt. Ltd.', 'UST Global',
#        'Tech Opportunity', 'Quantiphi', 'Mobotics', 'Maersk'],
#       dtype=object)

# %%
#8. Delete the rows which contains NaN values
df=df.dropna()
df
# Out:
#                                               job_title  \
# 5                                   Senior Data Analyst
# 7                               Machine Learning-Python
# 12                              Cloud Engineer (Remote)
# 16                           Machine Learning Developer
# 23                              Machine Learning Intern
# ...                                                 ...
# 1576                  Business Analyst - Manuel Testing
# 1579                                   Business Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# 1581  Program Research Analyst – Sustainable Cities ...
# 1582                                       Data Analyst
#
#                                              company  \
# 5                                     AdTech Holding
# 7                                               Atos
# 12                                   Julia Computing
# 16                                  Tech Opportunity
# ...

# %%
#9. Tell me the repeated number of salarys
df["job_salary"].value_counts()
# Out:
# ₹15,000 - ₹25,000 a month         11
# ₹10,000 - ₹15,000 a month          7
# ₹25,000 - ₹50,000 a month          6
# ₹10,00,000 - ₹15,00,000 a year     6
# ₹6,00,000 a year                   5
#                                   ..
# ₹3,40,000 a year                   1
# ₹3,60,000 - ₹8,40,000 a year       1
# ₹5,80,159 - ₹19,24,226 a year      1
# ₹7,15,000 - ₹7,95,000 a year       1
# ₹3,00,000 - ₹14,00,000 a year      1
# Name: job_salary, Length: 238, dtype: int64

# %%
#10. Show the bar plot of job salary, so that we can understand how many same job salary are there
import matplotlib.pyplot as plt
plt.figure(figsize=(100,20))
df["job_salary"].value_counts().plot(kind="bar")

# %%
#11. Change the date to 2022-08-06
df["today"]=df["today"].str.replace("2022-07-26","2022-08-06")
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                               job_title  \
# 5                                   Senior Data Analyst
# 7                               Machine Learning-Python
# 12                              Cloud Engineer (Remote)
# 16                           Machine Learning Developer
# 23                              Machine Learning Intern
# ...                                                 ...
# 1576                  Business Analyst - Manuel Testing
# 1579                                   Business Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# ...

# %%
#12. delete row number 5 form the dataset
df=df.drop([5],axis=0)
df
# Out:
#                                               job_title  \
# 7                               Machine Learning-Python
# 12                              Cloud Engineer (Remote)
# 16                           Machine Learning Developer
# 23                              Machine Learning Intern
# 25                                       Data Scientist
# ...                                                 ...
# 1576                  Business Analyst - Manuel Testing
# 1579                                   Business Analyst
# 1580         Research Analyst - Central Events (Hybrid)
# 1581  Program Research Analyst – Sustainable Cities ...
# 1582                                       Data Analyst
#
#                                              company  \
# 7                                               Atos
# 12                                   Julia Computing
# 16                                  Tech Opportunity
# 23                 Hacklab Solutions Private Limited
# ...
